# %%
import pandas as pd

# %%
data = pd.read_csv('final_merged_dataset.csv')

# %%
data.head(n = 10)
# Out:
#    Year  Month  EmployedClass - Total  \
# 0  2005      4              32221.085
# 1  2005      7              32521.695
# 2  2005     10              32875.281
# 3  2006      1              32031.302
# 4  2006      4              32698.970
# 5  2006      7              32925.757
# 6  2006     10              32885.759
# 7  2007      1              33545.365
# 8  2007      4              33703.914
# 9  2007      7              33318.046
#
#    EmployedClass - Wage and Salary Workers  \
# 0                                16296.384
# 1                                16303.519
# 2                                16552.683
# 3                                16086.126
# 4                                16543.649
# 5                                17406.980
# 6                                16655.804
# 7                                17911.440
# 8                                17232.094
# 9                                17691.607
#
#    EmployedClass - Worked for private household  \
# ...
